# %%
import pickle

# %%
/mnt/mnemo6/tao/nextflow/PPI_Coevolution/STRING_data_11.5/homologous_pp/SeqMapping/EggNogMaxLevel2_QuerySpe_ID511145andSubjectSpe_ID105422

# %%
with open("/mnt/mnemo6/tao/nextflow/PPI_Coevolution/STRING_data_11.5/homologous_pp/SeqMapping/EggNogMaxLevel2_QuerySpe_ID511145andSubjectSpe_ID105422/511145.b3916and105422.BBPM01000090_gene7329subject2query_AAmapDic_overlapMethodremove.pickle", 'rb') as handle:
    new=pickle.load(handle)

# %%
 new
# Out:
# {1: 7,
#  2: 8,
#  3: 9,
#  4: 10,
#  5: 11,
#  6: 12,
#  7: 13,
#  8: 14,
#  9: 15,
#  10: 16,
#  11: 17,
#  12: 18,
#  13: 19,
#  14: 20,
#  15: 21,
#  16: 22,
#  17: 23,
#  18: 24,
#  19: 25,
#  21: 26,
#  22: 27,
#  23: 28,
#  24: 29,
#  25: 30,
#  26: 31,
#  27: 32,
#  28: 33,
#  29: 34,
#  30: 35,
#  31: 36,
#  32: 37,
#  33: 38,
#  34: 39,
#  35: 40,
#  36: 41,
#  37: 42,
#  38: 43,
#  39: 44,
#  40: 45,
#  41: 46,
#  42: 47,
#  43: 48,
#  44: 49,
#  45: 50,
#  46: 51,
#  47: 52,
#  48: 53,
#  49: 54,
#  50: 55,
#  51: 56,
#  52: 57,
#  53: 58,
#  54: 59,
#  55: 60,
#  56: 61,
#  57: 62,
#  58: 63,
#  59: 64,
#  60: 65,
#  61: 66,
#  62: 67,
#  63: 68,
#  64: 69,
#  65: 70,
#  66: 71,
#  67: 72,
#  68: 73,
#  69: 74,
#  72: 75,
#  73: 76,
#  74: 77,
#  75: 78,
#  76: 79,
#  77: 80,
#  78: 81,
#  79: 82,
#  80: 83,
#  81: 84,
#  82: 85,
#  83: 86,
#  84: 87,
#  85: 90,
#  86: 91,
#  87: 92,
#  88: 93,
#  89: 94,
#  90: 95,
#  91: 96,
#  92: 97,
#  93: 98,
#  94: 99,
# ...

# %%
with open("/mnt/mnemo6/tao/PPI_Coevolution/STRING_data_11.5/homologous_pp/SeqMapping/EggNogMaxLevel2_SubjectSpe_ID511145andQuerySpe_ID105422/511145.b3916and105422.BBPM01000090_gene7329subject2query_AAmapDic_overlapMethodremove.pickle", 'rb') as handle:
    old=pickle.load(handle)
